# %%
import numpy as np
from collections import defaultdict
import networkx as nx

from cactus_generator import RandomCatusGenerator

# %%
13 3
0 1 
0 2
0 3 
0 4 
1 5
1 6 
2 7
2 8
3 9
3 10
4 11
4 12
(10)
# Out:
#   File "<ipython-input-3-d640c3fda6ee>", line 1
#     13 3
#        ^
# SyntaxError: invalid syntax

# %%
13 4
0 1 
0 2
0 3 
0 4 
1 5
1 6 
2 7
2 8
3 9
3 10
4 11
4 12
(13)
# Out:
#   File "<ipython-input-4-1430478985c1>", line 1
#     13 4
#        ^
# SyntaxError: invalid syntax

# %%
G = nx.Graph([[0, 1], 
[0, 2],
[0, 3], 
[0, 4 ], 
[1, 5], 
[1, 6 ], 
[2, 7], 
[2, 8], 
[3, 9], 
[3, 10], 
[4, 11], 
[4, 12]])

# %%
nx.draw_spring(G, with_labels=True)

# %%
13 4
12 1 
12 2
12 3 
12 4 
1 5
1 6 
2 7
2 8
3 9
3 10
4 11
4 0
(13)

# %%
5 6
0 1 0 2 0 3 0 4
(5)
