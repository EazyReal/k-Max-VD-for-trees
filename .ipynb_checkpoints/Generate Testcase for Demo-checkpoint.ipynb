# %%
import numpy as np
from collections import defaultdict
import networkx as nx
import time

from cactus_generator import RandomCatusGenerator

# %%
def generate1(n, k, p=0.5):
    T = nx.generators.trees.random_tree(n, int(time.time()))
    print(T.edges)
    print(n, k)
    for e in T.edges:
        print(e[0], e[1])
    #nx.draw(T,with_labels=True)
    print()
    nx.draw(T, with_labels=True)

# %%
generate1(15, 2, 0.2)
# Out:
# [(0, 13), (0, 11), (1, 5), (1, 11), (1, 6), (2, 8), (2, 3), (3, 13), (4, 13), (6, 12), (7, 12), (9, 14), (10, 11), (12, 14)]
# 15 2
# 0 13
# 0 11
# 1 5
# 1 11
# 1 6
# 2 8
# 2 3
# 3 13
# 4 13
# 6 12
# 7 12
# 9 14
# 10 11
# 12 14

# %%
es = [(0, 13), (0, 11), (1, 5), (1, 11), (1, 6), (2, 8), (2, 3), (3, 13), (4, 13), (6, 12), (7, 12), (9, 14), (10, 11), (12, 14)]
G = [[0]*15]*15
for i in range(15):
    for j in range(15):
        if((i,j) in es):
            G[i][j] = 1
H = nx.Graph(es)
nx.draw(H, with_labels=1)

# %%
generate1(100, 5)
# Out:
# [(0, 23), (0, 29), (1, 9), (2, 28), (2, 18), (3, 26), (3, 22), (4, 10), (4, 24), (4, 28), (5, 7), (5, 15), (6, 20), (7, 20), (8, 15), (9, 22), (9, 28), (11, 16), (11, 25), (11, 15), (12, 21), (12, 24), (13, 27), (13, 24), (14, 28), (15, 18), (17, 18), (18, 23), (19, 20)]
# 30 5
# 0 23
# 0 29
# 1 9
# 2 28
# 2 18
# 3 26
# 3 22
# 4 10
# 4 24
# 4 28
# 5 7
# 5 15
# 6 20
# 7 20
# 8 15
# 9 22
# 9 28
# 11 16
# 11 25
# 11 15
# 12 21
# 12 24
# 13 27
# 13 24
# 14 28
# 15 18
# 17 18
# 18 23
# 19 20
